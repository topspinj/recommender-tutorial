# %% [markdown]
# ## Part 2: Building a Recommendation System Using Implicit Feedback Data

# %% [markdown]
# In this tutorial, we will cover the most popular tools used for developing recommendation systems using implicit feedback.
#
# In specific, we will be exploring matrix factorization techniques from @benfred's [implicit](https://github.com/benfred/implicit) package.
